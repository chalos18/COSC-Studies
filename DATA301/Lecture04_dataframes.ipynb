# %%
# !pip install pystac_client
# !pip install planetary_computer
# !pip install odc-stac
# !pip install pandas
# !pip install pyarrow
# !pip install requests
# !pip install aiohttp
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import dask.array as da
import functools
#Create a 2D array that is the combined product table of 2 1D arrays, i.e.
#combined_prod([2 4], [3 1]) ->
#[[6 2]
#  [12 4]]

a = da.array([2, 4])
b = da.array([3, 1])

c = da.array([[1, 1], [2,2]])

a = 0.1232
print(abs(a))

#map(lambda x, y: x * y, zip(a,b))
# print(b[:,None].compute())

# I would like a to be represented as a 2 dimensional structure but I dont know how many elements are there 
# -> a[:, None] take all elements of the row element -> this is called broadcasting [row, column] 
# print((a[:, None] * b[:,None]).compute())
# print((a[:, None] * b[:,None].T).compute())

# ## sometimes it helps to solve the problem however you can and then think about how to modify your code

# result = list(map(lambda x: list(map(lambda y: (x * y).compute(), b)), a))
# print(result)
# print(a)

# def combined_prod(x, y):
#   return x[:, None] * y[None,:]

# print(combined_prod(a, b))
# print(combined_prod(a, b).compute())

# assert da.all(combined_prod(a, b) == da.array([[6, 2], [12, 4]])).compute()
# Out:
# 0.1232

# %%
import dask.dataframe as dd
#Read csv file
df = dd.read_csv("https://github.com/Opensourcefordatascience/Data-sets/raw/master/Iris_Data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Python313\Lib\site-packages\dask\backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File c:\Python313\Lib\site-packages\dask\dataframe\io\csv.py:731, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     718 def read(
#     719     urlpath,
#     720     blocksize="default",
#    (...)
#     729     **kwargs,
#     730 ):
# --> 731     return read_pandas(
#     732         reader,
#     733         urlpath,
#     734         blocksize=blocksize,
#     735         lineterminator=lineterminator,
#     736         compression=compression,
# ...

# %%
# first 50
df.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df['petal_length'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.describe().compute()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# sum, stdev
df['sepal_width'].std().compute()
# Out:
# 0.4335943113621737

# %%
# mean of first 50
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa

# %%
df_sorted = df.sort_values( by ='petal_length')
df_sorted.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
